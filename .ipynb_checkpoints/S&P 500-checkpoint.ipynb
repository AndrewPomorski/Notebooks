# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
SHORT_EMA_PERIOD = 12
LONG_EMA_PERIOD = 26

# %%
spy_data = pd.read_csv("SPY.csv")
spy_data.dropna(axis = 0)
spy_data.head()
spy_data = spy_data[0:300]
short_ema = spy_data.Close.ewm(span=12,min_periods=0,adjust=False).mean()
long_ema = spy_data.Close.ewm(span=26,min_periods=0,adjust=False).mean()

# %%
#plt.plot(spy_data.Close)
plt.plot(spy_data.index, short_ema)
plt.plot(spy_data.index, long_ema)
